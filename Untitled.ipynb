# %%
import ec_model
import numpy as np
import matplotlib.pyplot as plt
import test_data

# %%
loc = (-23.543196, -46.632432)
radius = 1000

# %%
(init_pop, logbook, pareto_ind, pharmacies, hospitals) = ec_model.run(loc, radius, test=True)
# Out:
# gen	evals	max                    	min                    	avg
# 0  	100  	[2.13786864 3.35963943]	[0.01488137 0.14986043]	[0.84578573 1.39515988]
# 1  	100  	[2.19661887 3.41573518]	[0.03134211 0.14986043]	[1.11007922 1.37619548]
# 2  	100  	[2.21757194 3.44511567]	[0.07558822 0.14986043]	[1.18931966 1.37762829]
# 3  	100  	[2.27667511 3.50213018]	[0.14986043 0.14986043]	[1.32652668 1.45740663]
# 4  	100  	[2.27667511 3.50213018]	[0.10975012 0.10975012]	[1.45092439 1.68432757]
# 5  	100  	[2.27667511 3.50213018]	[0.0836632 0.0836632]  	[1.42600477 1.57423323]
# 6  	100  	[2.27667511 3.50213018]	[0.0836632 0.0836632]  	[1.34511586 1.40455097]
# 7  	100  	[2.27667511 3.50213018]	[0.28979275 0.03745642]	[1.35986341 1.39862805]
# 8  	100  	[2.27667511 3.50213018]	[0.28979275 0.03745642]	[1.34788468 1.34371811]
# 9  	100  	[2.27667511 3.50213018]	[0.28979275 0.03745642]	[1.35579102 1.33596826]
# 10 	100  	[2.27667511 3.50213018]	[0.28979275 0.03745642]	[1.40129385 1.37943911]
# ...

# %%
logbook[1]['avg'][0]
# Out:
# 1.1100792188137905
